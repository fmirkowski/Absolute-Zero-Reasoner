# %%
# This was done on a remote jupyter server I was given access to so I have to solve it like this:

# %%
# !git clone https://github.com/fmirkowski/Absolute-Zero-Reasoner.git
# Out:
# NGC-DL-CONTAINER-LICENSE    get-pip.py	 libx32		   root      tmp
# bin			    home	 media		   run	     usr
# boot			    jupyter.log  mnt		   sbin      var
# cuda-keyring_1.1-1_all.deb  lib		 opt		   srv	     workspace
# dev			    lib32	 proc		   start.sh
# etc			    lib64	 requirements.txt  sys

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
from solver_pipeline import prompt, solver_pipeline
# Load model and tokenizer
model_name = "Qwen/Qwen3-4B"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)
print(f'answer: {solver_pipeline(prompt, model, tokenizer)}')
# Out:
# Running cells with '.venv (Python 3.13.3)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/Users/franek/projekty/ml/absoluter/Absolute-Zero-Reasoner/.venv/bin/python -m pip install ipykernel -U --force-reinstall'
